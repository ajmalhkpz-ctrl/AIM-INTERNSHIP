# %%
numbers = (10, 20, 30, 40,50)
print(numbers[0])
# Out:
# 10

# %%
students = ("Akash", "Rahul", "Anu", "Fathima")
print(students[-1])
# Out:
# Fathima

# %%
t = (10, 20, 30, 40)
print(len(t))
# Out:
# 4

# %%
countries = ("India", "USA", "Japan", "China","Brazil")
if"India" in countries:
    print("India exists")
else:
    print("India not found")
# Out:
# India exists

# %%
nums = (12, 45, 67, 23, 89)
print(max(nums))
# Out:
# 89

# %%
t = (1, 5, 2, 5, 3)
print(t.count(5))
# Out:
# 2

# %%
t1 = (1,2)
t2 = (3,4)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4)

# %%
animals = ("Tiger", "Dog", "Cat", "Elephant")
print(sorted(animals))
# Out:
# ['Cat', 'Dog', 'Elephant', 'Tiger']

# %%
languages = ("python", "java", "c++")
print(languages.index("java"))
# Out:
# 1

# %%
t = (10, 20, 30)
list = list(t)
print(list)
# Out:
# [10, 20, 30]
