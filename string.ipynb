# %%
x=5

# %%
x
# Out:
# 5

# %%
print(x)
# Out:
# 5

# %%
# entire phrase
phrase= 'statistics sits at the heart of machine learning'
print(phrase)
# Out:
# statistics sits at the heart of machine learning

# %%
# satement to get the type of the variable
type(phrase)
# Out:
# str

# %%
#single word
my_first_string='alegebra'
my_first_string
print(my_first_string)
# Out:
# alegebra

# %%
hash='#'
print(hash)
# Out:
# #

# %%
#we can simply declare a string
'deep learning'
# Out:
# 'deep learning'

# %%
# note that we can't output multiple string this way 
'linear algebra'
'calculus'
# Out:
# 'calculus'

# %%
sentence="i'm using single quotes,but this will create an error"
print(sentence)
# Out:
# i'm using single quotes,but this will create an error

# %%
print('linear algebra')
print('calculus')
print('use \n to printa new line')
print('\n')
print('see what \n i mean?')
# Out:
# linear algebra
# calculus
# use
#  to printa new line
#
#
# see what
#  i mean?

# %%
print("shahid ahammed")
# Out:
# shahid ahammed

# %%
sentence="python is easy"
print("first word:",sentence[0])
print("last word:",sentence[-1])
# Out:
# first word: p
# last word: y

# %%
text="shrishti campus"
print("total number:",len(text))
# Out:
# total number: 15

# %%
text="team work"
print(text.title())
# Out:
# Team Work

# %%
sentence="python language"
print(sentence.replace(" ","-"))
# Out:
# python-language

# %%
sentence="i am learning python today"
if"python"in sentence:
    print("python exists in the sentence")
else:
    print("python does not exist")
# Out:
# python exists in the sentence

# %%
fruits="banana,apple,water melon"
print(fruits.split(","))
# Out:
# ['banana', 'apple', 'water melon']

# %%
movie="INTERSTELLAR"
print(movie.lower())
# Out:
# interstellar
