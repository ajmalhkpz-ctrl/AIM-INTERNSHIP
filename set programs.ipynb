# %%
numbers = {10, 20, 30, 40, 50}
print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
cities = {"Mumbai", "Chennai"}
cities.add("Delhi")
print(cities)
# Out:
# {'Mumbai', 'Chennai', 'Delhi'}

# %%
subjects = {"Maths", "Science", "English"}
subjects.remove("Science")
print(subjects)
# Out:
# {'Maths', 'English'}

# %%
s = {10, 20, 30, 40, 50}
if 50 in s:
    print("50 exists")
else:
    print("50 not found")
# Out:
# 50 exists

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5}

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}
print(s1.intersection(s2))
# Out:
# {2, 3}

# %%
brands = {"Samsung", "Vivo", "Realmi", "Motorola"}
print(len(brands))
# Out:
# 4

# %%
s = {1, 2, 3, 4}
s.clear()
print(s)
# Out:
# set()

# %%
s = {10, 20, 30}
s.update([40, 50, 60])
print(s)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
lst = [1, 2, 2, 3, 3, 4]
s = set(lst)
print(s)
# Out:
# {1, 2, 3, 4}
