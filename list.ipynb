# %%
subjects=["maths","science","english","history","computer"]
print(subjects[0])
# Out:
# maths

# %%
numbers=[10, 20, 30, 40, 50]
print(numbers[-1])
# Out:
# 50

# %%
brands = ["sumsung", "vivo", "oppo", "realmi"]
brands.append("motorola")
print(brands)
# Out:
# ['sumsung', 'vivo', 'oppo', 'realmi', 'motorola']

# %%
students=["Ajmal", "Shahid", "Akash", "adithyan", "ajul"]
print("total names:",len(students))
# Out:
# total names: 5

# %%
numbers=[10,20,30,40]
numbers[2]=35
print(numbers)
# Out:
# [10, 20, 35, 40]

# %%
subjects = ["Science", "Maths", "English"]
subjects.remove("English")
print(subjects)
# Out:
# ['Science', 'Maths']

# %%
numbers=[15,40,25,60,10]
print("maximum value:",max(numbers))
# Out:
# maximum value: 60
